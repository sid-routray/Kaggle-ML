# %%
# import pulp
from pulp import LpVariable, LpProblem, LpMaximize, LpStatus, value, LpMinimize

# Problem (Knapsack Initial)
# define variables
x1 = LpVariable("x1", 0, 1, cat = 'Integer')
x2 = LpVariable("x2", 0, 1, cat = 'Integer')
x3 = LpVariable("x3", 0, 1, cat = 'Integer')
x4 = LpVariable("x4", 0, 1, cat = 'Integer')

# defines the problem
prob = LpProblem("problem", LpMaximize)
# Note, LpMaximize for a maximization problem, 
# and LpMinimize for a minimization problem

# define constraints
prob += 4*x1 + 5*x2 + 7*x3 + 3*x4 <= 14

# Note, if <= then <=
# If >= then >=
# If = then ==

# define objective function
prob += 12*x1 + 16*x2 + 22*x3 + 8*x4

# solve the problem
status = prob.solve()
print(f"Problem")
print(f"status={LpStatus[status]}")

# print the results
for variable in prob.variables():
    print(f"{variable.name} = {variable.varValue}")
    
print(f"Objective = {value(prob.objective)}")
print(f"")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/vy/ttqf684x6j59_vcfzj1wtd7h0000gn/T/cd65e529d03048248aed8323c0f764c5-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/vy/ttqf684x6j59_vcfzj1wtd7h0000gn/T/cd65e529d03048248aed8323c0f764c5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 23 RHS
# At line 25 BOUNDS
# At line 30 ENDATA
# Problem MODEL has 1 rows, 4 columns and 4 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 44 - 0.00 seconds
# Cgl0004I processed model has 1 rows, 4 columns (4 integer (4 of which binary)) and 4 elements
# Cutoff increment increased from 1e-05 to 1.9999
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.5
# Cbc0038I Pass   1: suminf.    0.28571 (1) obj. -43.7143 iterations 1
# Cbc0038I Solution found of -28
# Cbc0038I Rounding solution of -36 is better than previous of -28
#
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1 rows 4 columns, reduced to 1 rows 2 columns
# Cbc0038I Mini branch and bound improved solution from -36 to -38 (0.01 seconds)
# Cbc0038I Round again with cutoff of -40.3999
# Cbc0038I Pass   2: suminf.    0.28571 (1) obj. -43.7143 iterations 0
# Cbc0038I Pass   3: suminf.    0.43637 (1) obj. -40.3999 iterations 1
# Cbc0038I Pass   4: suminf.    0.28571 (1) obj. -43.7143 iterations 1
# Cbc0038I Pass   5: suminf.    0.28571 (1) obj. -43.7143 iterations 0
# Cbc0038I Pass   6: suminf.    0.39999 (1) obj. -40.3999 iterations 2
# Cbc0038I Pass   7: suminf.    0.28571 (1) obj. -43.7143 iterations 2
# Cbc0038I Pass   8: suminf.    0.28571 (1) obj. -43.7143 iterations 0
# Cbc0038I Pass   9: suminf.    0.39999 (1) obj. -40.3999 iterations 2
# Cbc0038I Pass  10: suminf.    0.39999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  11: suminf.    0.39999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  12: suminf.    0.19999 (1) obj. -40.3999 iterations 1
# Cbc0038I Pass  13: suminf.    0.43637 (1) obj. -40.3999 iterations 1
# Cbc0038I Pass  14: suminf.    0.39999 (1) obj. -40.3999 iterations 1
# Cbc0038I Pass  15: suminf.    0.39999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  16: suminf.    0.39999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  17: suminf.    0.39999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  18: suminf.    0.39999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  19: suminf.    0.39999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  20: suminf.    0.39999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  21: suminf.    0.19999 (1) obj. -40.3999 iterations 1
# Cbc0038I Pass  22: suminf.    0.19999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  23: suminf.    0.19999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  24: suminf.    0.19999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  25: suminf.    0.19999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  26: suminf.    0.19999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  27: suminf.    0.19999 (1) obj. -40.3999 iterations 0
# Cbc0038I Pass  28: suminf.    0.28571 (1) obj. -43.7143 iterations 2
# Cbc0038I Pass  29: suminf.    0.43637 (1) obj. -40.3999 iterations 1
# Cbc0038I Pass  30: suminf.    0.28571 (1) obj. -43.7143 iterations 1
# Cbc0038I Pass  31: suminf.    0.43637 (1) obj. -40.3999 iterations 1
# Cbc0038I Rounding solution of -42 is better than previous of -38
#
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1 rows 4 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -43.9999
# Cbc0038I Reduced cost fixing fixed 3 variables on major pass 3
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -42 - took 0.00 seconds
# Cbc0012I Integer solution of -42 found by feasibility pump afterProblem
# status=Optimal
# x1 = 1.0
# x2 = 0.0
# x3 = 1.0
# x4 = 1.0
# Objective = 42.0
#
#  0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 1 rows 4 columns, reduced to 0 rows 0 columns
# Cbc0001I Search completed - best objective -42, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 3 variables fixed on reduced cost
# Cuts at root node changed objective from -44 to -38
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                42.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01

# %%
# Problem (Racecar)
# define variables
x1 = LpVariable("x1", 0, 1, cat = 'Integer')
x2 = LpVariable("x2", 0, 1, cat = 'Integer')
x3 = LpVariable("x3", 0, 1, cat = 'Integer')
x4 = LpVariable("x4", 0, 1, cat = 'Integer')
x5 = LpVariable("x5", 0, 1, cat = 'Integer')
x6 = LpVariable("x6", 0, 1, cat = 'Integer')

# defines the problem
prob = LpProblem("problem", LpMaximize)
# Note, LpMaximize for a maximization problem, 
# and LpMinimize for a minimization problem

# define constraints
prob += 10200*x1 + 6000*x2 + 23800*x3 + 11100*x4 + 9800*x5 + 31600*x6 <= 35000

# Note, if <= then <=
# If >= then >=
# If = then ==

# define objective function
prob += 8*x1 + 3*x2 + 15*x3 + 7*x4 + 10*x5 + 12*x6

# solve the problem
status = prob.solve()
print(f"Problem")
print(f"status={LpStatus[status]}")

# print the results
for variable in prob.variables():
    print(f"{variable.name} = {variable.varValue}")
    
print(f"Objective = {value(prob.objective)}")
print(f"")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/vy/ttqf684x6j59_vcfzj1wtd7h0000gn/T/afbe7d52cda24f44967fedde2842caf1-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/vy/ttqf684x6j59_vcfzj1wtd7h0000gn/T/afbe7d52cda24f44967fedde2842caf1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 31 RHS
# At line 33 BOUNDS
# At line 40 ENDATA
# Problem MODEL has 1 rows, 6 columns and 6 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 27.458 - 0.00 seconds
# Cgl0004I processed model has 1 rows, 6 columns (6 integer (6 of which binary)) and 6 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.163866
# Cbc0038I Solution found of -25
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1 rows 6 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of -26.1457
# Cbc0038I Reduced cost fixing fixed 3 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.07638 (1) obj. -26.1457 iterations 1
# Cbc0038I Pass   2: suminf.    0.16387 (1) obj. -27.458 iterations 1
# Cbc0038I Pass   3: suminf.    0.07638 (1) obj. -26.1457 iterations 1
# Cbc0038I Pass   4: suminf.    0.16387 (1) obj. -27.458 iterations 1
# Cbc0038I Pass   5: suminf.    0.16387 (1) obj. -27.458 iterations 0
# Cbc0038I Pass   6: suminf.    0.16387 (1) obj. -27.458 iterations 0
# Cbc0038I Pass   7: suminf.    0.16387 (1) obj. -27.458 iterations 0
# Cbc0038I Pass   8: suminf.    0.16387 (1) obj. -27.458 iterations 0
# Cbc0038I Pass   9: suminf.    0.16387 (1) obj. -27.458 iterations 0
# Cbc0038I Pass  10: suminf.    0.07638 (1) obj. -26.1457 iterations 1
# Cbc0038I Pass  11: suminf.    0.45695 (1) obj. -26.1457 iterations 1
# Cbc0038I Pass  12: suminf.    0.36975 (1) obj. -27.4538 iterations 1
# Cbc0038I Pass  13: suminf.    0.45695 (1) obj. -26.1457 iterations 1
# Cbc0038I Pass  14: suminf.    0.45695 (1) obj. -26.1457 iterations 0
# Cbc0038I Pass  15: suminf.    0.45695 (1) obj. -26.1457 iterations 0
# Cbc0038I Pass  16: suminf.    0.45695 (1) obj. -26.1457 iterations 0
# Cbc0038I Pass  17: suminf.    0.36975 (1) obj. -27.4538 iterations 1
# Cbc0038I Pass  18: suminf.    0.45695 (1) obj. -26.1457 iterations 1
# Cbc0038I Pass  19: suminf.    0.07638 (1) obj. -26.1457 iterations 1
# Cbc0038I Pass  20: suminf.    0.07638 (1) obj. -26.1457 iterations 0
# Cbc0038I Pass  21: suminf.    0.07638 (1) obj. -26.1457 iterations 0
# Cbc0038I Pass  22: suminf.    0.07638 (1) obj. -26.1457 iterations 0
# Cbc0038I Pass  23: suminf.    0.45695 (1) obj. -26.1457 iterations 1
# Cbc0038I Pass  24: suminf.    0.36975 (1) obj. -27.4538 iterations 1
# Cbc0038I Pass  25: suminf.    0.18919 (1) obj. -26.6757 iterations 2
# Cbc0038I Pass  26: suminf.    0.18919 (1) obj. -26.6757 iterations 0
# Cbc0038I Pass  27: suminf.    0.34305 (1) obj. -26.1457 iterations 2
# Cbc0038I Pass  28: suminf.    0.37815 (1) obj. -26.6723 iterations 1
# Cbc0038I Pass  29: suminf.    0.34305 (1) obj. -26.1457 iterations 1
# Cbc0038I Pass  30: suminf.    0.37815 (1) obj. -26.6723 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1 rows 6 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -25 - took 0.00 seconds
# Cbc0012I Integer solution of -25 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -26.95 to -26.95 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts averagProblem
# status=Optimal
# x1 = 1.0
# x2 = 0.0
# x3 = 0.0
# x4 = 1.0
# x5 = 1.0
# x6 = 0.0
# Objective = 25.0
#
# e 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -25, took 1 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 4 variables fixed on reduced cost
# Cuts at root node changed objective from -27.458 to -26.95
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                25.00000000
# Enumerated nodes:               0
# Total iterations:               1
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01

# %%
# Moving to California Problem

# import pulp
from pulp import LpVariable, LpProblem, LpMaximize, LpStatus, value, LpMinimize

# Problem (Knapsack Initial)
# define variables
BedRoom = LpVariable("Bedroom set", 0, 1, cat = 'Integer')
DinRoom = LpVariable("Dining room set", 0, 1, cat = 'Integer')
GameC = LpVariable("Gaming computer", 0, 1, cat = 'Integer')
Sofa = LpVariable("Sofa", 0, 1, cat = 'Integer')
Tv = LpVariable("TV", 0, 1, cat = 'Integer')

# defines the problem
prob = LpProblem("problem", LpMaximize)
# Note, LpMaximize for a maximization problem, 
# and LpMinimize for a minimization problem

# define constraints
prob += 800 * BedRoom + 600 * DinRoom + 300 * GameC + 400 * Sofa + 200 * Tv <= 1100

# Note, if <= then <=
# If >= then >=
# If = then ==

# define objective function
prob += 60 * BedRoom + 48 * DinRoom + 14 * GameC + 31 * Sofa + 10 * Tv 

# solve the problem
status = prob.solve()
print(f"Problem")
print(f"status={LpStatus[status]}")

# print the results
for variable in prob.variables():
    print(f"{variable.name} = {variable.varValue}")
    
print(f"Objective = {value(prob.objective)}")
print(f"")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /usr/local/anaconda3/lib/python3.9/site-packages/pulp/apis/../solverdir/cbc/osx/64/cbc /var/folders/vy/ttqf684x6j59_vcfzj1wtd7h0000gn/T/d4766fd8796343b3a6cd889b86ddf193-pulp.mps max timeMode elapsed branch printingOptions all solution /var/folders/vy/ttqf684x6j59_vcfzj1wtd7h0000gn/T/d4766fd8796343b3a6cd889b86ddf193-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 27 RHS
# At line 29 BOUNDS
# At line 35 ENDATA
# Problem MODEL has 1 rows, 5 columns and 5 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 86.5 - 0.00 seconds
# Cgl0004I processed model has 1 rows, 5 columns (5 integer (5 of which binary)) and 5 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.125
# Cbc0038I Solution found of -79
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1 rows 5 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I Round again with cutoff of -80.6499
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.02750 (1) obj. -80.6499 iterations 1
# Cbc0038I Pass   2: suminf.    0.12500 (1) obj. -86.5 iterations 1
# Cbc0038I Pass   3: suminf.    0.12500 (1) obj. -86.5 iterations 0
# Cbc0038I Pass   4: suminf.    0.17250 (1) obj. -80.6499 iterations 2
# Cbc0038I Pass   5: suminf.    0.12500 (1) obj. -83.5 iterations 1
# Cbc0038I Pass   6: suminf.    0.17250 (1) obj. -80.6499 iterations 1
# Cbc0038I Pass   7: suminf.    0.37089 (2) obj. -80.6499 iterations 2
# Cbc0038I Pass   8: suminf.    0.16667 (1) obj. -81 iterations 2
# Cbc0038I Pass   9: suminf.    0.37089 (2) obj. -80.6499 iterations 2
# Cbc0038I Pass  10: suminf.    0.37089 (2) obj. -80.6499 iterations 0
# Cbc0038I Pass  11: suminf. Problem
# status=Optimal
# Bedroom_set = 0.0
# Dining_room_set = 1.0
# Gaming_computer = 0.0
# Sofa = 1.0
# TV = 0.0
# Objective = 79.0
#
#    0.12500 (1) obj. -83.5 iterations 2
# Cbc0038I Pass  12: suminf.    0.43021 (1) obj. -80.6499 iterations 3
# Cbc0038I Pass  13: suminf.    0.37500 (1) obj. -85.5 iterations 2
# Cbc0038I Pass  14: suminf.    0.45583 (1) obj. -80.6499 iterations 1
# Cbc0038I Pass  15: suminf.    0.43021 (1) obj. -80.6499 iterations 1
# Cbc0038I Pass  16: suminf.    0.43021 (1) obj. -80.6499 iterations 0
# Cbc0038I Pass  17: suminf.    0.43021 (1) obj. -80.6499 iterations 0
# Cbc0038I Pass  18: suminf.    0.43021 (1) obj. -80.6499 iterations 0
# Cbc0038I Pass  19: suminf.    0.69749 (2) obj. -80.6499 iterations 3
# Cbc0038I Pass  20: suminf.    0.17250 (1) obj. -80.6499 iterations 1
# Cbc0038I Pass  21: suminf.    0.12500 (1) obj. -83.5 iterations 1
# Cbc0038I Pass  22: suminf.    0.69749 (2) obj. -80.6499 iterations 1
# Cbc0038I Pass  23: suminf.    0.69749 (2) obj. -80.6499 iterations 0
# Cbc0038I Pass  24: suminf.    0.69749 (2) obj. -80.6499 iterations 0
# Cbc0038I Pass  25: suminf.    0.69749 (2) obj. -80.6499 iterations 0
# Cbc0038I Pass  26: suminf.    0.69749 (2) obj. -80.6499 iterations 0
# Cbc0038I Pass  27: suminf.    0.75554 (2) obj. -80.6499 iterations 2
# Cbc0038I Pass  28: suminf.    0.37500 (1) obj. -85.5 iterations 3
# Cbc0038I Pass  29: suminf.    0.45583 (1) obj. -80.6499 iterations 1
# Cbc0038I Pass  30: suminf.    0.37500 (1) obj. -85.5 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1 rows 5 columns, reduced to 1 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -79 - took 0.00 seconds
# Cbc0012I Integer solution of -79 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -86.5 to -86.5 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -79, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Cuts at root node changed objective from -86.5 to -86.5
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                79.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
