# %%
# 2

from sympy import Symbol, solveset, lambdify, Interval, oo  # oo is sympys representation of Infinity
from sympy.plotting import plot
from math import floor

x = Symbol('x')  # Set a symbol
P = 2*x**3 + 18*x**2 + 48*x - 7   # Equation for rents
P_fun = lambdify(x, P)
der_P = P.diff(x)  # derivitive of F

dRoots = solveset(der_P, x, Interval(-10, 10)) # Find the roots of our derivitive where x is between -5 and 5
y_vals = [P_fun(r) for r in dRoots]
print(f"Extreme values are {dRoots} at y values of {y_vals} respectively") # gives a set with a single extrema, this is our answer
# Out:
# Extreme values are FiniteSet(-4, -2) at y values of [-39, -47] respectively

# %%
# 5
import sympy
import math

x = sympy.Symbol('x')
f = 8 * sympy.sqrt(x) + 2
f_prime = f.diff(x)

sympy.plotting.plot(f_prime)
sympy.plotting.plot(f)



#print ( (f.subs(x, 6) - f.subs(x, 4))/(6-4) )
#print (f.subs(x, 6))
#print ( round(((8*math.sqrt(6)+2)-18)/2, 4) )

#(4/1.798)**2

print ( (4/1.798)**2 )
# Out:
# 4.949263858866791

# %%
# 5
import sympy
import math

x = sympy.Symbol('x')
f = 2 * x**3 - 5*x
f_prime = f.diff(x)

sympy.plotting.plot(f_prime)
sympy.plotting.plot(f)



print ( (f.subs(x, -3) - f.subs(x, -1))/(-3+1) )
f_prime
#6x**2 - 5 = 21, 6x**2 = 26, x**2 = 26/6, x = math.sqrt(13/3)
#print (f.subs(x, 6))
#print ( round(((8*math.sqrt(6)+2)-18)/2, 4) )

#(4/1.798)**2

print ( math.sqrt(13/3) )
# Out:
# 21
# 2.0816659994661326

# %%
# 7
from sympy import Symbol, lambdify, plotting

x = Symbol('x')
g = 8 * x **3 - 96 * x**2 + 360 * x
g_first = g.diff(x)
g_second = g_first.diff(x)

print(f"First derivitive is {g_first}")
print(f"Second derivitive is {g_second}")

g_first_f = lambdify(x, g_first)
g_second_f = lambdify(x, g_second)

p1 = g_second_f(5)

print(f"g''(-5) = {p1}")

gp = plotting.plot(g, show=False, ylim=(-1000, 1000), line_color='b', label='g', legend=True)
gp1 = plotting.plot(g_first, show=False, line_color='r', label="g'")
gp2 = plotting.plot(g_second, show=False, line_color='g', label="g''")

gp.append(gp1[0])
gp.append(gp2[0])
gp.show()

print("We can visually verify our interpretation of concave down and a maxima")
48*5 -192
# Out:
# First derivitive is 24*x**2 - 192*x + 360
# Second derivitive is 48*x - 192
# g''(-5) = 48
# We can visually verify our interpretation of concave down and a maxima
# 48

# %%
from sympy import Symbol, lambdify, plotting

x = Symbol('x')
g = (170*x)/((x+2)**2) 
g_first = g.diff(x)
g_second = g_first.diff(x)

print(f"First derivitive is {g_first}")
print(f"Second derivitive is {g_second}")

g_first_f = lambdify(x, g_first)
g_second_f = lambdify(x, g_second)

p1 = g_second_f(10)

print(f"g''(10) = {p1}")

gp = plotting.plot(g, show=False, ylim=(0, 100), line_color='b', label='g', legend=True)
gp1 = plotting.plot(g_first, show=False, line_color='r', label="g'")
gp2 = plotting.plot(g_second, show=False, line_color='g', label="g''")

gp.append(gp1[0])
gp.append(gp2[0])
gp.show()

print("We can visually verify our interpretation of concave down and a maxima")
# 10x -20 = 0, x = 2 
print( round(math.sqrt(18750/1.5), 4) )
# 340x/u3 = 170/u2 , 2x/u = 1, u = 2x, x+2=2x,  x = 2
g.subs(x,2)
85.0/4
# Out:
# First derivitive is -340*x/(x + 2)**3 + 170/(x + 2)**2
# Second derivitive is 1020*x/(x + 2)**4 - 680/(x + 2)**3
# g''(10) = 0.0983796296296296
# We can visually verify our interpretation of concave down and a maxima
# 111.8034
# 21.25

# %%
# 14 
from sympy import Symbol, lambdify, solve, plotting, oo

t = Symbol('t')
S = (240 * t) / (t + 3)**2

S_prime = S.diff(t)

print("Sales Plot")
plotting.plot(S, xlim=(0, 15), ylim=(0, 100))


dRoots = solveset(S_prime, t, Interval(0, oo)) # Find the roots of our derivitive where x is between 0 and infinity
print(f"Extreme values are {dRoots}") # gives a set with a single extrema, this is our answer

S_func = lambdify(t, S)  # Turn the symbolic equation into a callable function so we can find the S(t) for our found t value
max_val = S_func(dRoots.args[0])
print(f"Maximum profit is {max_val * 1000} and occurs at {dRoots.args[0]}")
# Out:
# Sales Plot
# Extreme values are FiniteSet(3)
# Maximum profit is 20000 and occurs at 3

# %%
from sympy import Symbol, lambdify, plotting

x = Symbol('x')
g = 5*x + 4/x
g_first = g.diff(x)
g_second = g_first.diff(x)

print(f"First derivitive is {g_first}")
print(f"First derivitive is {g_first}")
print(f"Second derivitive is {g_second}")

dRoots = solveset(g_first, x, Interval(0, oo)) # Find the roots of our derivitive where x is between 0 and infinity
print(f"Extreme values are {dRoots}") # gives a set with a single extrema, this is our answer

print ( 2*(math.sqrt(5)/5) )

g_first_f = lambdify(x, g_first)
g_second_f = lambdify(x, g_second)

p1 = g_second_f(10)

print(f"g''(10) = {p1}")

gp = plotting.plot(g, show=False, ylim=(0, 100), line_color='b', label='g', legend=True)
gp1 = plotting.plot(g_first, show=False, line_color='r', label="g'")
gp2 = plotting.plot(g_second, show=False, line_color='g', label="g''")

gp.append(gp1[0])
gp.append(gp2[0])
gp.show()

print("We can visually verify our interpretation of concave down and a maxima")
# Out:
# First derivitive is 5 - 4/x**2
# First derivitive is 5 - 4/x**2
# Second derivitive is 8/x**3
# Extreme values are FiniteSet(2*sqrt(5)/5)
# 0.894427190999916
# g''(10) = 0.008
# We can visually verify our interpretation of concave down and a maxima
